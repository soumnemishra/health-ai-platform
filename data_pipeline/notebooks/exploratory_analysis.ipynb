# %% [markdown]
# # Exploratory Data Analysis
#
# This notebook contains exploratory analysis of ingested papers.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Set style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# %%
# Load data
# df = pd.read_csv('data/papers.csv')
# or from database
# from scripts.db_utils import get_papers
# papers = get_papers(limit=10000)
# df = pd.DataFrame(papers)

print("Data loaded successfully")

# %%
# Basic statistics
# print(f"Total papers: {len(df)}")
# print(f"Date range: {df['publication_date'].min()} to {df['publication_date'].max()}")
# print(f"Average citations: {df['citations'].mean():.2f}")

# %%
# Visualizations
# fig, axes = plt.subplots(2, 2, figsize=(15, 10))
# 
# # Citations distribution
# axes[0, 0].hist(df['citations'], bins=50)
# axes[0, 0].set_title('Citations Distribution')
# axes[0, 0].set_xlabel('Citations')
# axes[0, 0].set_ylabel('Frequency')
# 
# # Publications over time
# df['year'] = pd.to_datetime(df['publication_date']).dt.year
# yearly_counts = df['year'].value_counts().sort_index()
# axes[0, 1].plot(yearly_counts.index, yearly_counts.values)
# axes[0, 1].set_title('Publications Over Time')
# axes[0, 1].set_xlabel('Year')
# axes[0, 1].set_ylabel('Count')
# 
# plt.tight_layout()
# plt.show()
